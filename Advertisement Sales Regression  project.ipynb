# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Lenovo\\Downloads\\Advertising.csv")

# %%
df.head()
# Out:
#        TV  radio  newspaper  sales
# 0  230100  37800      69200  22100
# 1   44500  39300      45100  10400
# 2   17200  45900      69300   9300
# 3  151500  41300      58500  18500
# 4  180800  10800      58400  12900

# %% [markdown]
# # data preprecessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    int64
#  1   radio      200 non-null    int64
#  2   newspaper  200 non-null    int64
#  3   sales      200 non-null    int64
# dtypes: int64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df.describe()
# Out:
#                   TV         radio      newspaper         sales
# count     200.000000    200.000000     200.000000    200.000000
# mean   147042.500000  23264.000000   30554.000000  14022.500000
# std     85854.236315  14846.809176   21778.620839   5217.456566
# min       700.000000      0.000000     300.000000   1600.000000
# 25%     74375.000000   9975.000000   12750.000000  10375.000000
# 50%    149750.000000  22900.000000   25750.000000  12900.000000
# 75%    218825.000000  36525.000000   45100.000000  17400.000000
# max    296400.000000  49600.000000  114000.000000  27000.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.drop(["newspaper"],axis=1,inplace=True)

# %%
df.head()
# Out:
#        TV  radio  sales
# 0  230100  37800  22100
# 1   44500  39300  10400
# 2   17200  45900   9300
# 3  151500  41300  18500
# 4  180800  10800  12900

# %%
X=df[["TV","radio"]]
y=df["sales"]

# %%
#train_test_split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=True)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 2947.5150360289954

# %%
model.coef_
# Out:
# array([0.04686997, 0.1800065 ])

# %%
#Prediction train data and test dat
ypred_train=model.predict(x_train)
ypred_test=model.predict(x_test)

# %%
#Evaluation on  train data and test data

# %%
#Evaluation on  train data and test data

from sklearn.metrics import r2_score
print("Train_r2_score:",r2_score(y_train,ypred_train))
print("Test_r2_score:",r2_score(y_test,ypred_test))

#cross validation score
from sklearn.model_selection import cross_val_score
print("CV_score:",cross_val_score(model,x_train,y_train,cv=5).mean())
# Out:
# Train_r2_score: 0.8958528468776601
# Test_r2_score: 0.8947344950027067
# CV_score: 0.8870547969149675

# %%
#linearity of error

# %%
error=y_test-ypred_test
plt.scatter(y_test,error)
plt.xlabel("observed_values")
plt.ylabel("fitted_values")
plt.show()

# %%
#normality of error

# %%
sns.kdeplot(error)
# Out:
# <Axes: xlabel='sales', ylabel='Density'>

# %%
#equal varience of error

# %%
plt.scatter(ypred_test,error,c="r")
plt.axhline(y=0,color="green")
plt.xlabel("fitted_value")
plt.ylabel("residuals")
# Out:
# Text(0, 0.5, 'residuals')

# %%
sns.kdeplot(error)
# Out:
# <Axes: xlabel='sales', ylabel='Density'>

# %%
plt.scatter(ypred_test,error,c="r")
plt.axhline(y=0,color="green")
plt.xlabel("fitted_value")
plt.ylabel("resdeise")
# Out:
# Text(0, 0.5, 'resdeise')

# %% [markdown]
# # polynomal Regresion

# %%
df=pd.read_csv("C:\\Users\\Lenovo\\Downloads\\Advertising.csv")

# %%
df.head()
# Out:
#        TV  radio  newspaper  sales
# 0  230100  37800      69200  22100
# 1   44500  39300      45100  10400
# 2   17200  45900      69300   9300
# 3  151500  41300      58500  18500
# 4  180800  10800      58400  12900

# %% [markdown]
# # Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    int64
#  1   radio      200 non-null    int64
#  2   newspaper  200 non-null    int64
#  3   sales      200 non-null    int64
# dtypes: int64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %% [markdown]
# # Expolratory Data Analysis

# %%
df.describe()
# Out:
#                   TV         radio      newspaper         sales
# count     200.000000    200.000000     200.000000    200.000000
# mean   147042.500000  23264.000000   30554.000000  14022.500000
# std     85854.236315  14846.809176   21778.620839   5217.456566
# min       700.000000      0.000000     300.000000   1600.000000
# 25%     74375.000000   9975.000000   12750.000000  10375.000000
# 50%    149750.000000  22900.000000   25750.000000  12900.000000
# 75%    218825.000000  36525.000000   45100.000000  17400.000000
# max    296400.000000  49600.000000  114000.000000  27000.000000

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
IQR=45100-12750
IQR
# Out:
# 32350

# %%
lower=12750-(IQR*1.5)
lower
# Out:
# -35775.0

# %%
upper=45100+(IQR*1.5)
upper
# Out:
# 93625.0

# %%
df[(df["newspaper"]<lower) | (df["newspaper"]>upper)]
# Out:
#          TV  radio  newspaper  sales
# 16    67800  36600     114000  12500
# 101  296400  36300     100900  23800

# %%
df["newspaper"]=df["newspaper"].clip(lower=-35775.0,upper=93625.0)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.kdeplot(df)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.059325  0.782224
# radio      0.054809  1.000000   0.355953  0.576223
# newspaper  0.059325  0.355953   1.000000  0.231432
# sales      0.782224  0.576223   0.231432  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
continous=["TV","radio","newspaper","sales"]

# %%
continous
# Out:
# ['TV', 'radio', 'newspaper', 'sales']

# %%
X=df[["TV","radio","newspaper"]]
y=df["sales"]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=True)

# %%
y_test.shape
# Out:
# (40,)

# %% [markdown]
# # polynomal Regresion

# %%
from sklearn.preprocessing import PolynomialFeatures                                                  #polynomal Regresion

# %%
polynomial_converter=PolynomialFeatures(degree=3)

# %%
x_train_poly=pd.DataFrame(polynomial_converter.fit_transform(x_train))
x_test_poly=pd.DataFrame(polynomial_converter.fit_transform(x_test))

# %%
from sklearn.linear_model import  LinearRegression

model=LinearRegression()

model.fit(x_train_poly,y_train)
# Out:
# LinearRegression()

# %%
#Predicton on Train data and test data

ypred_train=model.predict(x_train_poly)
ypred_test=model.predict(x_test_poly)

# %%
#Evaluation
from sklearn.metrics import mean_squared_error,r2_score
print("MSE:",mean_squared_error(y_train,ypred_train))
print("Train_R2_score:",r2_score(y_train,ypred_train))
print("Test_R2_score:",r2_score(y_test,ypred_test))
#cross validation score
from sklearn.model_selection import cross_val_score

print("CV_score:",cross_val_score(model,x_train_poly,y_train,cv=5).mean())
# Out:
# MSE: 230174.2554817808
# Train_R2_score: 0.992060355361671
# Test_R2_score: 0.9901047594081162
# CV_score: 0.9855973005055485
